# %%
from lem import config, get_E1

get_E1(config.cpcdh())

# %%
from lem import align_E1, config

align_E1(config.cpcdh())

# %%
from lem import config, init_trajectory

init_trajectory(config.cpcdh())

# %%
from lem import config, draw_trajectory

draw_trajectory(config.cpcdh())
