# %%
from lem import config, get_E1

get_E1(config.cpcdh())

# %%
from lem import align_E1, config

align_E1(config.cpcdh())

# %%
from lem import Snapshot, config
from polychrom_hoomd import render

snapshot = Snapshot(config.cpcdh())()

png_output_file = config.cpcdh()["data_dir"] / "output" / "initial.png"
# Visualize starting conformation using the Fresnel backend (A compartments in blue, B in red)
render.fresnel(snapshot, show="compartments", cmap="coolwarm").static(
    pathtrace=False, png_output_file=png_output_file
)
