# %%
from lem import config, hic

cfg = config.cpcdh()
hic.get_E1(cfg)
# Out:
# /home/ljw/new_fold/projects/pcdh_sim_projects/lem/.conda/lib/python3.12/site-packages/cooltools/lib/common.py:489: UserWarning: less than 50% of valid bins have been assigned a value
#   warnings.warn("less than 50% of valid bins have been assigned a value")

# %%
from lem import config, hic

cfg = config.cpcdh()
hic.align_E1(cfg)

# %%
from lem import config, hic

cfg = config.cpcdh()
hic.align_CBS(cfg)

# %%
from lem import config, init_trajectory

cfg = config.cpcdh()
init_trajectory(cfg)
# Out:
# notice(3): Device is running on CPU
# notice(3): GSD: create or overwrite gsd file /home/ljw/sdc1/cpcdh/output/trajectory.gsd

# %%
from lem import config, warmup

cfg = config.cpcdh()
warmup(cfg)
# Out:
# notice(3): Device is running on CPU
# notice(3): data.gsd_snapshot: open gsd file /home/ljw/sdc1/cpcdh/output/trajectory.gsd
# Setting up DPD with the conservative force contribution disabled
# notice(3): GSD: check frame 0 in gsd file /home/ljw/sdc1/cpcdh/output/trajectory.gsd
# notice(3): GSD: open gsd file /home/ljw/sdc1/cpcdh/output/trajectory.gsd

# %%
from lem import config, loop_extrusion_3d

cfg = config.cpcdh()
loop_extrusion_3d(cfg, steps=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lem import config, loop_extrusion_3d
#       2
#       3 cfg = config.cpcdh()
#       4 loop_extrusion_3d(cfg, steps=50)
#
# File ~/new_fold/projects/pcdh_sim_projects/lem/lem/__init__.py:12
#       9 import pandas as pd
#      10 from matplotlib.ticker import EngFormatter
# ---> 12 import polychrom_hoomd.extrude
#      13 import polychrom_hoomd.forces
#      14 import polychrom_hoomd.log
#
# File ~/new_fold/projects/pcdh_sim_projects/lem/polychrom_hoomd/extrude.py:11
#       8 import cupy as xp
#       9 dpath = os.path.dirname(os.path.abspath(__file__))
# ---> 11 with open(f'{dpath}/kernels/lef_spatial_utils.cuh', 'r') as cuda_file:
#      12     cuda_code = cuda_file.read()
#      13     cuda_module = xp.RawModule(code=cuda_code, options=('--use_fast_math',))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ljw/new_fold/projects/pcdh_sim_projects/lem/polychrom_hoomd/kernels/lef_spatial_utils.cuh'

# %%
from lem import config, draw_trajectory

cfg = config.cpcdh()
draw_trajectory(cfg)
